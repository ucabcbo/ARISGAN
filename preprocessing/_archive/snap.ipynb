# %% [markdown]
# #### Collocate and cut imagery

# %%
import sys
sys.path.append('..')
import init
# Out:
# init loaded

# %%
import os
import sys
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

sys.path.append(os.path.expanduser('~/.snap/snap-python'))
import snappy
from snappy import ProductIO
from snappy import jpy
HashMap = snappy.jpy.get_type('java.util.HashMap')

sys.path.append('../')
import sis_toolbox as tbx
import preprocessing.snap_toolbox as stbx

# %%
img_pairs_inventory = pd.read_csv(os.path.join(init.DATA_ROOT, 'inventory/img_pairs.csv'), index_col='index')
s2images = img_pairs_inventory['s2'].drop_duplicates()
# s2images

# %%
# Visually inspect S2 images one by one

sample_index = 274
s2sample = s2images[sample_index]
s2_raw = ProductIO.readProduct(s2sample)

print(sample_index)
print(os.path.basename(s2sample))
print(f'Cloud percentage: {stbx.s2_metadata_cloud_percentage(s2_raw)}')
stbx.plot_tile(s2_raw, 's2')
# Out:
# 274
# S2B_MSIL1C_20220402T171849_N0400_R012_T17XPA_20220402T192945.SAFE
# Cloud percentage: 77.878586998716

# %%
sample_index = 260
s2image = s2images[sample_index]
s2_raw = ProductIO.readProduct(s2image)
s3_images = img_pairs_inventory[img_pairs_inventory['s2'] == s2images[sample_index]]['s3']

# %%
from datetime import datetime

print('Index\t\tOverlap\t\tTimediff.')
print('-------------------------------------------')
for row_index in s3_images.index:
    s3_raw = ProductIO.readProduct(s3_images[row_index])
    print(row_index, end='\t\t')
    row = img_pairs_inventory.iloc[row_index]
    print(round(stbx.check_overlap(s2_raw, s3_raw, type_master="metadata.s2", type_slave="metadata.s3"),3), end='\t\t')
    s2_date = datetime.strptime(row['s2_date'], '%Y-%m-%d %H:%M:%S')
    s3_date = datetime.strptime(row['s3_date'], '%Y-%m-%d %H:%M:%S')
    difference_minutes = int(abs((s2_date - s3_date).total_seconds() / 60))
    print(difference_minutes)
    print('')
# Out:
# Index		Overlap		Timediff.
# -------------------------------------------
# 260		0.724		1369
#
# 261		0.274		1366
#
# 262		0.0		54
#
# 263		0.052		43
#
# 264		0.947		46
#
# 265		0.0		1359

# %%
img_pair = img_pairs_inventory.iloc[31]
s3_raw = ProductIO.readProduct(img_pair['s3'])
print(f'overlap: {round(stbx.check_overlap(s2_raw, s3_raw, type_master="metadata.s2", type_slave="metadata.s3"),3)}')
stbx.plot_polygons(s2_raw, s3_raw, [])

img_pair
# Out:
# overlap: 0.146
# <class 'list'>
# s2                  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# s2_date                                           2022-04-22 17:18:49
# s3                  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# s3_date                                           2022-04-23 15:48:23
# delta                                                 0 days 22:29:34
# status_0704                                              tifs created
# possible overlap                                                    1
# overlap                                                          0.99
# status                                                   tifs created
# Name: 31, dtype: object

# %%
### 0717: tile creation for curated images

curated_pairs = [34,
                 41,
                 47,
                 77,
                 81,
                 89,
                 103,
                 126,
                 141,
                 149,
                 170,
                 178,
                 264]

# %%
img_index = curated_pairs[0]
img_pair = img_pairs_inventory.iloc[img_index]

s2_raw = ProductIO.readProduct(img_pair['s2'])
s3_raw = ProductIO.readProduct(img_pair['s3'])

s2_bands = stbx.band_subset(s2_raw, 'B2,B3,B4')
s3_bands = stbx.band_subset(s3_raw, 'Oa01_radiance,Oa02_radiance,Oa03_radiance,Oa04_radiance,Oa05_radiance,Oa06_radiance,Oa07_radiance,Oa08_radiance,Oa09_radiance,Oa10_radiance,Oa11_radiance,Oa12_radiance,Oa13_radiance,Oa14_radiance,Oa15_radiance,Oa16_radiance,Oa17_radiance,Oa18_radiance,Oa19_radiance,Oa20_radiance,Oa21_radiance')
# s2_bands = stbx.resample(s2_bands, 'B2')
collocated = stbx.collocate(s2_bands, s3_bands)
collocated = stbx.band_subset(collocated,'B2,B3,B4,Oa01_radiance,Oa02_radiance,Oa03_radiance,Oa04_radiance,Oa05_radiance,Oa06_radiance,Oa07_radiance,Oa08_radiance,Oa09_radiance,Oa10_radiance,Oa11_radiance,Oa12_radiance,Oa13_radiance,Oa14_radiance,Oa15_radiance,Oa16_radiance,Oa17_radiance,Oa18_radiance,Oa19_radiance,Oa20_radiance,Oa21_radiance,quality_flags,collocationFlags')

s2_polygon = stbx.get_metadata_polygon(s2_raw, 's2')
s3_polygon = stbx.get_metadata_polygon(s3_raw, 's3')

# %%
tile_list, quality_list = stbx.cut_tiles(collocated,
                                        tilesize=init.TILESIZE,
                                        file_index=img_index,
                                        output_path=init.DATA_ROOT,
                                        save_if_errors=False,
                                        ensure_intersect_with=[s2_polygon,s3_polygon],
                                        cloud_threshold=1.0)

# %%
#### END
assert 1 == 0

# %%
# for index, row in img_pairs_inventory.iterrows():
#     S2_FILE = row['s2']
#     S3_FILE = row['s3']
#     s2_raw = ProductIO.readProduct(S2_FILE)
#     s3_raw = ProductIO.readProduct(S3_FILE)
#     overlap = snap_toolbox.check_overlap(s2_raw, s3_raw)
#     img_pairs_inventory.loc[index, 'overlap'] = round(overlap,2)
#     s2_raw.dispose()
#     s3_raw.dispose()

# %%
PAIR_INDEX = 26

# %%
### DO ALL FOLLOWING ONLY IF STATUS = NEW
pd.isna(img_pairs_inventory['status'].iloc[PAIR_INDEX]) or img_pairs_inventory['status'].iloc[PAIR_INDEX] == 'new'
# Out:
# False

# %%
row = img_pairs_inventory.iloc[PAIR_INDEX]

S2_FILE = row['s2']
S3_FILE = row['s3']
print(row['s2'])
print(row['s3'])
# Out:
# /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_2/DATA/S2B_MSIL1C_20220406T165839_N0400_R069_T17XPA_20220406T210753.SAFE
# /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_3/OLCI/2022/04/S3A_OL_1_EFR____20220406T162930_20220406T163230_20220407T204845_0179_084_026_1620_MAR_O_NT_002.SEN3

# %%
### LOCAL ONLY!!!
S2_FILE = '/Users/christianboehm/projects/sis2/data/sample_00013/S2B_MSIL1C_20220428T173859_N0400_R098_T17XPA_20220428T205006.SAFE'
S3_FILE = '/Users/christianboehm/projects/sis2/data/sample_00013/S3A_OL_1_EFR____20220428T152128_20220428T152428_20220429T200056_0179_084_339_1800_MAR_O_NT_002.SEN3'

# %%
# def get_collocated_image(S2_FILE, S3_FILE):

# Reading raw images
s2_raw = ProductIO.readProduct(S2_FILE)
s3_raw = ProductIO.readProduct(S3_FILE)
# Out:
# INFO: org.esa.s2tbx.dataio.gdal.GDALVersion: Internal GDAL 3.0.0 set to be used by SNAP.
# INFO: org.esa.s2tbx.dataio.s2.ortho.S2OrthoProductReaderPlugIn: Building product reader - EPSG:32617
# WARNING: org.esa.snap.core.metadata.GenericXmlMetadata: Metadata: the path to element [metadata_level] does not exist
# WARNING: org.esa.snap.core.metadata.GenericXmlMetadata: Metadata: the path to element [granuleidentifier] does not exist
# WARNING: org.esa.snap.core.metadata.GenericXmlMetadata: Metadata: the path to element [bandid] does not exist
# INFO: org.hsqldb.persist.Logger: dataFileCache open start

# %%
overlap = stbx.check_overlap(s2_raw, s3_raw, 'metadata.s2', 'metadata.s3')
print(overlap)

img_pairs_inventory.loc[PAIR_INDEX, 'possible overlap'] = overlap
# Out:
# 1.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 overlap = snap_toolbox.check_overlap(s2_raw, s3_raw, 'metadata.s2', 'metadata.s3')
#       2 print(overlap)
# ----> 4 img_pairs_inventory.loc[PAIR_INDEX, 'possible overlap'] = overlap
#
# NameError: name 'img_pairs_inventory' is not defined

# %%
polygon_real_s2 = stbx.get_metadata_polygon(s2_raw, 's2')

# %%
polygon_real_s3 = stbx.get_metadata_polygon(s3_raw, 's3')

# %%
### Do all following only if overlap == 1.0

if overlap < 1:
    img_pairs_inventory.loc[PAIR_INDEX, 'status'] = 'no overlap'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 ### Do all following only if overlap == 1.0
#       3 if overlap < 1:
# ----> 4     img_pairs_inventory.loc[PAIR_INDEX, 'status'] = 'no overlap'
#
# NameError: name 'img_pairs_inventory' is not defined

# %%
img_pairs_inventory
# Out:
#                                                       s2              s2_date  \
# index
# 0      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-26 17:49:11
# 1      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-26 17:49:11
# 2      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-26 17:49:11
# 3      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-26 17:49:11
# 4      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-26 17:49:11
# ...                                                  ...                  ...
# 276    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 17:18:49
# 277    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 17:18:49
# 278    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 17:18:49
# 279    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 17:18:49
# 280    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 17:18:49
#
#                                                       s3              s3_date  \
# index
# 0      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-27 17:25:38
# 1      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-27 15:47:39
# 2      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-27 15:44:39
# 3      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-26 17:51:49
# 4      /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-26 16:13:50
# ...                                                  ...                  ...
# 276    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 18:14:13
# 277    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 16:36:14
# 278    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 16:33:14
# 279    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 14:55:15
# 280    /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...  2022-04-02 14:52:15
#
#                  delta   status_0704  possible overlap  overlap        status
# index
# 0      0 days 23:36:27    no overlap            0.0000     1.00  tifs created
# 1      0 days 21:58:28  tifs created            1.0000     0.06  overlap <90%
# 2      0 days 21:55:28  tifs created            1.0000     0.94  tifs created
# 3      0 days 00:02:38    no overlap            0.0000     0.99  tifs created
# 4      0 days 01:35:21  tifs created            1.0000     0.00  overlap <90%
# ...                ...           ...               ...      ...           ...
# 276    0 days 00:55:24    no overlap            0.0000     0.03  overlap <90%
# 277    0 days 00:42:35    no overlap            0.0000     0.00  overlap <90%
# 278    0 days 00:45:35  tifs created            1.0000     1.00           new
# 279    0 days 02:23:34    no overlap            0.2063     0.28  overlap <90%
# 280    0 days 02:26:34    no overlap            0.0000     0.00  overlap <90%
#
# [281 rows x 9 columns]

# %%
# snap_toolbox.plot_tile(s2_raw)

# %%
s2_bands = stbx.band_subset(s2_raw, 'B2,B3,B4,B_opaque_clouds')
# s2_bands = snap_toolbox.band_subset(s2_raw, 'B2,B3,B4')
# snap.plot_tile(s2_bands)
# Out:
# 100% done.

# %%
s3_bands = stbx.band_subset(s3_raw, 'Oa01_radiance,Oa02_radiance,Oa03_radiance,Oa04_radiance,Oa05_radiance,Oa06_radiance,Oa07_radiance,Oa08_radiance,Oa09_radiance,Oa10_radiance,Oa11_radiance,Oa12_radiance,Oa13_radiance,Oa14_radiance,Oa15_radiance,Oa16_radiance,Oa17_radiance,Oa18_radiance,Oa19_radiance,Oa20_radiance,Oa21_radiance')
# snap_toolbox.plot_s3_tile(s3_bands)
# Out:
# 100% done.

# %%
s2_bands = stbx.resample(s2_bands, 'B2')
# Out:
# 100% done.

# %%
collocated = stbx.collocate(s2_bands, s3_raw, resampling_method='BILINEAR_INTERPOLATION')
# Out:
# 100% done.

# %%
# WEIRD collocation behaviour on image 00013
temp = stbx.region_subset(collocated, '2883,1056,256,256')
# WEIRD collocation behaviour on image 00075
# temp = snap_toolbox.region_subset(collocated, '3405,2883,256,256')
# Out:
# 100% done.

# %%
stbx.plot_tile(temp, 's2')
# Out:
# ../sis_toolbox.py:4: RuntimeWarning: invalid value encountered in true_divide
#   return (array - array_min) / (array_max - array_min)

# %%
stbx.plot_tile(temp, 's3')

# %%
from shapely.geometry import Polygon

polygon_s2 = stbx.get_bbox_polygon(s2_raw)
polygon_s3 = stbx.get_bbox_polygon(s3_raw)
polygon_temp = stbx.get_bbox_polygon(temp)


fig, ax = plt.subplots(figsize=(10,10))

# Plot the polygons
ax.plot(*polygon_s2.exterior.xy, color='palegreen', linestyle='dashed', linewidth=1, label='S2 bbox')
ax.plot(*polygon_s3.exterior.xy, color='lightblue', linestyle='dashed', linewidth=1, label='S3 bbox')
ax.plot(*polygon_real_s2.exterior.xy, color='green', label='S2 actual')
ax.plot(*polygon_real_s3.exterior.xy, color='blue', label='S3 actual')
ax.plot(*polygon_temp.exterior.xy, color='red', label='Tile')
# ax.plot(*polygon_s2.intersection(polygon_s3).exterior.xy, color='black', label='joint')
# ax.plot(*polygon_s2.intersection(polygon_s3).envelope.exterior.xy, color='green', label='map')

# Set plot limits
# ax.set_xlim(45, 90)
# ax.set_ylim(-90, -45)
# ax.set_xlim(70, 74)
# ax.set_ylim(-82, -72)

# Add legend
ax.legend()

# Show the plot
plt.show()

# %%
print(polygon_real_s2.intersection(polygon_real_s3).area / polygon_real_s2.area)
print(stbx.check_overlap(s2_raw, s3_raw, 'metadata.s2', 'metadata.s3'))
print(stbx.check_overlap(s2_raw, s3_raw))
# Out:
# 0.9999999999999997
# S2B_MSIL1C_20220428T173859_N0400_R098_T17XPA_20220428T205006
# S3A_OL_1_EFR____20220428T152128_20220428T152428_20220429T200056_0179_084_339_1800_MAR_O_NT_002.SEN3
# 0.9999999999999997
# 0.7705852463402368

# %%
collocated = stbx.band_subset(collocated,'B2,B3,B4,Oa01_radiance,Oa02_radiance,Oa03_radiance,Oa04_radiance,Oa05_radiance,Oa06_radiance,Oa07_radiance,Oa08_radiance,Oa09_radiance,Oa10_radiance,Oa11_radiance,Oa12_radiance,Oa13_radiance,Oa14_radiance,Oa15_radiance,Oa16_radiance,Oa17_radiance,Oa18_radiance,Oa19_radiance,Oa20_radiance,Oa21_radiance,B_opaque_clouds,quality_flags,collocationFlags')

# %%
temp = stbx.region_subset(collocated, '1000,1000,960,960')

# %%
ProductIO.writeProduct(temp, '/home/cb/sis2/data/temp4.tif', 'GeoTIFF')

# %%
band = temp.getBand('Oa17_radiance')
# band = collocated.getBand('B2')
width = band.getRasterWidth()
height = band.getRasterHeight()
nparray = np.zeros(100*100, dtype=np.float32)
band.readPixels(0,0,100,100,nparray)

max_value = np.max(nparray)
count = np.count_nonzero(nparray == max_value)

print(max_value)
print(count / nparray.size)
    
min_value = np.min(nparray)
count = np.count_nonzero(nparray == min_value)

print(min_value)
print(count / nparray.size)

# nparray.shape = (height,width)

# snap.plot_s3_tile(collocated)
# Out:
# 132.48495
# 0.0371
# 131.68137
# 0.0101

# %%
s2_raw.dispose()
s3_raw.dispose()
s2_bands.dispose()
s3_bands.dispose()

# %%
temp = stbx.region_subset(collocated, '0,0,200,200')

# %%
ProductIO.writeProduct(temp, '/home/cb/sis2/data/temp2.tif', 'GeoTIFF')

# %%
# tile_list, quality_list = snap.cut_tiles(collocated, TILESIZE, PAIR_INDEX, PATH_DATA)
# tile_inventory.head(50)
# tile_inventory[tile_inventory['status'] == 'ok']

# %%
img_pairs_inventory.loc[PAIR_INDEX, 'status'] = 'tifs created'

# %%
img_pairs_inventory.to_csv(os.path.join(PATH_DATA, 'inventory/img_pairs.csv'))

# %%
tile_list.keys()
# Out:
# dict_keys(['20x20', '20x1018', '20x2016', '20x3014', '1018x20', '1018x1018', '1018x2016', '2016x1018', '3014x20', '3014x1018', '4012x20'])

# %%
file_inventory.at[PAIR_INDEX, f'status_{TILESIZE}'] = 'created'

# %%
tile_inventory.head(50)
# Out:
#    img_index        tile  size   status  \
# 0      00004       20x20   960       ok
# 1      00004     20x1018   960       ok
# 2      00004     20x2016   960       ok
# 3      00004     20x3014   960       ok
# 4      00004     20x4012   960  quality
# 5      00004     20x5010   960  quality
# 6      00004     20x6008   960  quality
# 7      00004     20x7006   960  quality
# 8      00004     20x8004   960  quality
# 9      00004     20x9002   960  quality
# 10     00004    20x10000   960    error
# 11     00004     1018x20   960       ok
# 12     00004   1018x1018   960       ok
# 13     00004   1018x2016   960       ok
# 14     00004   1018x3014   960  quality
# 15     00004   1018x4012   960  quality
# 16     00004   1018x5010   960  quality
# 17     00004   1018x6008   960  quality
# 18     00004   1018x7006   960  quality
# 19     00004   1018x8004   960  quality
# 20     00004   1018x9002   960  quality
# 21     00004  1018x10000   960    error
# 22     00004     2016x20   960  quality
# 23     00004   2016x1018   960       ok
# 24     00004   2016x2016   960  quality
# 25     00004   2016x3014   960  quality
# 26     00004   2016x4012   960  quality
# 27     00004   2016x5010   960  quality
# 28     00004   2016x6008   960  quality
# 29     00004   2016x7006   960  quality
# 30     00004   2016x8004   960  quality
# 31     00004   2016x9002   960  quality
# 32     00004  2016x10000   960    error
# 33     00004     3014x20   960       ok
# 34     00004   3014x1018   960       ok
# 35     00004   3014x2016   960  quality
# 36     00004   3014x3014   960  quality
# 37     00004   3014x4012   960  quality
# 38     00004   3014x5010   960  quality
# 39     00004   3014x6008   960  quality
# 40     00004   3014x7006   960  quality
# 41     00004   3014x8004   960  quality
# 42     00004   3014x9002   960  quality
# 43     00004  3014x10000   960    error
# 44     00004     4012x20   960       ok
# 45     00004   4012x1018   960  quality
# 46     00004   4012x2016   960  quality
# 47     00004   4012x3014   960  quality
# 48     00004   4012x4012   960  quality
# 49     00004   4012x5010   960  quality
#
#                                               comment  \
# 0
# 1
# 2
# 3
# 4                                 cloud coverage: 76%
# 5                                 cloud coverage: 94%
# 6                                 cloud coverage: 93%
# 7                                cloud coverage: 100%
# 8                               black proportion: 33%
# 9                               black proportion: 91%
# 10  org.esa.snap.core.gpf.OperatorException: gridH...
# 11
# 12
# 13
# 14                                cloud coverage: 35%
# 15                                cloud coverage: 99%
# 16                                cloud coverage: 43%
# 17                              black proportion: 11%
# 18                              black proportion: 72%
# 19                             black proportion: 100%
# 20                             black proportion: 100%
# 21  org.esa.snap.core.gpf.OperatorException: gridH...
# 22                                cloud coverage: 30%
# 23
# 24                                cloud coverage: 32%
# 25                                cloud coverage: 41%
# 26                                cloud coverage: 57%
# 27                              black proportion: 46%
# 28                              black proportion: 97%
# 29                             black proportion: 100%
# 30                             black proportion: 100%
# 31                             black proportion: 100%
# 32  org.esa.snap.core.gpf.OperatorException: gridH...
# 33
# 34
# 35                                cloud coverage: 68%
# 36                              black proportion: 22%
# 37                              black proportion: 83%
# 38                             black proportion: 100%
# 39                             black proportion: 100%
# 40                             black proportion: 100%
# 41                             black proportion: 100%
# 42                             black proportion: 100%
# 43  org.esa.snap.core.gpf.OperatorException: gridH...
# 44
# 45                               black proportion: 5%
# 46                              black proportion: 60%
# 47                              black proportion: 99%
# 48                             black proportion: 100%
# 49                             black proportion: 100%
#
#                                              filename
# 0   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 1   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 2   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 3   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 4   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 5   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 6   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 7   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 8   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 9   /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 10  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 11  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 12  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 13  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 14  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 15  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 16  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 17  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 18  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 19  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 20  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 21  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 22  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 23  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 24  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 25  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 26  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 27  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 28  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 29  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 30  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 31  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 32  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 33  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 34  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 35  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 36  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 37  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 38  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 39  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 40  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 41  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 42  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 43  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 44  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 45  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 46  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 47  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 48  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...
# 49  /cpnet/projects/sikuttiaq/pond_inlet/Sentinel_...

# %%
# tile = tile_list[list(tile_list.keys())[15]]
tile = quality_list['20x4012']

# %%
import importlib
importlib.reload(stbx)
# Out:
# <module 'snap' from '/home/cb/sis2/preprocessing/snap.py'>

# %%
# Reading raw images
s2_raw = ProductIO.readProduct(S2_FILE)
s3_raw = ProductIO.readProduct(S3_FILE)

# %%
stbx.plot_s3_tile(collocated)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-e6b77771fc12> in <module>()
# ----> 1 snap.plot_s3_tile(collocated)
#
# /home/cb/sis2/preprocessing/snap.py in plot_s3_tile(product, figsize)
#     102     # Extract the bands for red, green, and blue
#     103
# --> 104     red_data = helper.normalize_numpy(nparray(product, 'Oa17_radiance'))
#     105     green_data = helper.normalize_numpy(nparray(product, 'Oa06_radiance'))
#     106     blue_data = helper.normalize_numpy(nparray(product, 'Oa03_radiance'))
#
# /home/cb/sis2/preprocessing/snap.py in nparray(product, bandname)
#      74     height = band.getRasterHeight()
#      75     nparray = np.zeros(width*height, dtype=np.float32)
# ---> 76     band.readPixels(0,0,width,height,nparray)
#      77     nparray.shape = (height,width)
#      78     return nparray
#
# RuntimeError: java.lang.IllegalArgumentException: [sourceGeoCoding] is null
